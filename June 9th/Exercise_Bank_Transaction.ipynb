# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Bank_Transactions').getOrCreate()

# %%
transactions = [
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT"
]
rdd = spark.sparkContext.parallelize(transactions)

# %%
# 1
rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
# 2
rdd.count()
# Out:
# 50

# %%
# 3
rdd.take(1)
# Out:
# ['DEPOSIT']

# %%
# 4
rdd.take(15)
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER']

# %%
# 5
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
# 6
rdd.distinct().count()
# Out:
# 5

# %%
# 7
rdd.sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
# 8
rdd.map(lambda x: x.lower()).collect()
# Out:
# ['deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'balance_check',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'deposit']

# %%
# 9
rdd.map(lambda x: x.upper()).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
# 10
rdd.map(lambda x: (x,len(x))).collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
# 11
rdd.filter(lambda x: x == "DEPOSIT").collect()
# Out:
# ['DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT']

# %%
# 12
rdd.filter(lambda x: x == "WITHDRAW").collect()
# Out:
# ['WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
# 13
rdd.filter(lambda x: x == "TRANSFER").collect()
# Out:
# ['TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER']

# %%
# 14
rdd.filter(lambda x: x == "LOAN_PAYMENT").collect()
# Out:
# ['LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT']

# %%
# 15
rdd.filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
# 16
rdd.filter(lambda x: x != "DEPOSIT").collect()
# Out:
# ['WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'BALANCE_CHECK']

# %%
# 17
rdd.filter(lambda x: x != "TRANSFER").collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
# 18
rdd.filter(lambda x: len(x) > 8).collect()
# Out:
# ['BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK']

# %%
# 19
rdd.filter(lambda x: len(x) < 10).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT']

# %%
# 20
rdd.filter(lambda x: x.startswith("B")).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
# 21
rdd.map(lambda x : "BANK_"+x).collect()
# Out:
# ['BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
# ...

# %%
# 22
rdd.map(lambda x: x+"_2025").collect()
# Out:
# ['DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
# ...

# %%
# 23
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
# 24
rdd.map(lambda x: (x, 1)).collect()
# Out:
# [('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
# ...

# %%
# 25
rdd.map(lambda x: x.replace("DEPOSIT", "CASH_DEPOSIT")).collect()
# Out:
# ['CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT']

# %%
# 26
rdd.map(lambda x: x.replace("WITHDRAW", "CASH_WITHDRAW")).collect()
# Out:
# ['DEPOSIT',
#  'CASH_WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
# 27
rdd.map(lambda x: x[::-1]).collect()
# Out:
# ['TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED']

# %%
# 28
rdd.map(lambda x: x[:3]).collect()
# Out:
# ['DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'WIT',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'TRA',
#  'DEP',
#  'WIT',
#  'DEP',
#  'TRA',
#  'BAL',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'BAL',
#  'DEP',
#  'TRA',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'BAL',
#  'DEP']

# %%
# 29
rdd.map(lambda x: x[-4:]).collect()
# Out:
# ['OSIT',
#  'DRAW',
#  'SFER',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'MENT',
#  'OSIT',
#  'SFER',
#  'DRAW',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'MENT',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'HECK',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'MENT',
#  'OSIT',
#  'DRAW',
#  'SFER',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'MENT',
#  'OSIT',
#  'DRAW',
#  'SFER',
#  'HECK',
#  'OSIT',
#  'SFER',
#  'DRAW',
#  'MENT',
#  'OSIT',
#  'SFER',
#  'HECK',
#  'OSIT']

# %%
# 30
rdd.map(lambda x:"D" if x == "DEPOSIT"
    else "W" if x == "WITHDRAW"
    else "T" if x == "TRANSFER"
    else x
).collect()
# Out:
# ['D',
#  'W',
#  'T',
#  'D',
#  'BALANCE_CHECK',
#  'T',
#  'D',
#  'W',
#  'LOAN_PAYMENT',
#  'D',
#  'T',
#  'W',
#  'D',
#  'BALANCE_CHECK',
#  'T',
#  'D',
#  'W',
#  'LOAN_PAYMENT',
#  'T',
#  'D',
#  'W',
#  'D',
#  'T',
#  'BALANCE_CHECK',
#  'W',
#  'D',
#  'T',
#  'LOAN_PAYMENT',
#  'D',
#  'W',
#  'T',
#  'D',
#  'BALANCE_CHECK',
#  'T',
#  'W',
#  'D',
#  'T',
#  'LOAN_PAYMENT',
#  'D',
#  'W',
#  'T',
#  'BALANCE_CHECK',
#  'D',
#  'T',
#  'W',
#  'LOAN_PAYMENT',
#  'D',
#  'T',
#  'BALANCE_CHECK',
#  'D']

# %%
# 31
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
# 32
rdd.distinct().count()
# Out:
# 5

# %%
# 33
rdd.distinct().sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
# 34
rdd.distinct().filter(lambda x:"PAYMENT" in x).collect()
# Out:
# ['LOAN_PAYMENT']

# %%
# 35
rdd.distinct().filter(lambda x:"CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
# 36
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 16,
#              'WITHDRAW': 10,
#              'TRANSFER': 13,
#              'BALANCE_CHECK': 6,
#              'LOAN_PAYMENT': 5})

# %%
# 37
counts = rdd.countByValue()
most = max(counts.items(), key=lambda x: x[1])
print(most)
# Out:
# ('DEPOSIT', 16)

# %%
# 38
least = min(counts.items(), key=lambda x: x[1])
print(least)
# Out:
# ('LOAN_PAYMENT', 5)

# %%
counts
# Out:
# defaultdict(int,
#             {'DEPOSIT': 16,
#              'WITHDRAW': 10,
#              'TRANSFER': 13,
#              'BALANCE_CHECK': 6,
#              'LOAN_PAYMENT': 5})

# %%
# 39
print(counts)
# Out:
# defaultdict(<class 'int'>, {'DEPOSIT': 16, 'WITHDRAW': 10, 'TRANSFER': 13, 'BALANCE_CHECK': 6, 'LOAN_PAYMENT': 5})

# %%
# 40
[transactions for transactions, count in counts.items() if count > 5]
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK']

# %%
extra_transactions = [
"DEPOSIT",
"ATM_WITHDRAWAL",
"TRANSFER",
"MOBILE_RECHARGE",
"BALANCE_CHECK"
]
rdd2 = spark.sparkContext.parallelize(extra_transactions)

# %%
# 41
rdd.union(rdd2).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'ATM_WITHDRAWAL',
#  'TRANSFER',
#  'MOBILE_RECHARGE',
#  'BALANCE_CHECK']

# %%
# 42
rdd.union(rdd2).count()
# Out:
# 55

# %%
# 43
rdd.union(rdd2).distinct().collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'ATM_WITHDRAWAL',
#  'MOBILE_RECHARGE']

# %%
# 44
rdd2.subtract(rdd).collect()
# Out:
# ['ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
# 45
rdd.union(rdd2).countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 17,
#              'WITHDRAW': 10,
#              'TRANSFER': 14,
#              'BALANCE_CHECK': 7,
#              'LOAN_PAYMENT': 5,
#              'ATM_WITHDRAWAL': 1,
#              'MOBILE_RECHARGE': 1})

# %%
rdd3 = spark.sparkContext.parallelize([
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"CREDIT_CARD_PAYMENT",
"ATM_WITHDRAWAL"
])

# %%
# 46
rdd.intersection(rdd3).collect()
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
# 47
rdd.intersection(rdd3).count()
# Out:
# 3

# %%
# 48
rdd.intersection(rdd3).sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'TRANSFER']

# %%
# 49
rdd.intersection(rdd3).filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
# 50
rdd.intersection(rdd3).filter(lambda x: "TRANSFER" in x).collect()
# Out:
# ['TRANSFER']

# %%
amounts = [
500,1200,3000,4500,800,950,
1100,2500,4000,6000,
750,1800,2200,3300,4700,
5200,1500,2600,3700,4800,
5900,6200,700,900,1400,
1750,2100,2900,3600,4300,
5100,5800,6500,7200,8100,
9200,10500,12000,13500,15000,
17000,19000,22000,25000,28000,
30000,32000,35000,38000,40000
]
amount_rdd = spark.sparkContext.parallelize(amounts)

# %%
# 51
amount_rdd.reduce(lambda x,y: x+y)
# Out:
# 463750

# %%
# 52
tot = amount_rdd.reduce(lambda x,y: x+y)
cnt = amount_rdd.count()
average = tot / cnt
average
# Out:
# 9275.0

# %%
# 53
amount_rdd.reduce(lambda x,y: x if x>y else y)
# Out:
# 40000

# %%
# 54
amount_rdd.reduce(lambda x,y: x if x<y else y)
# Out:
# 500

# %%
# 55
amount_rdd.filter(lambda x: x > 1000).count()
# Out:
# 14

# %%
# 56
amount_rdd.filter(lambda x: x < 2000).count()
# Out:
# 12

# %%
# 55
amount_rdd.filter(lambda x: x > 10000).collect()
# Out:
# [10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
# 56
amount_rdd.filter(lambda x: x < 2000).collect()
# Out:
# [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]

# %%
# 57
amount_rdd.map(lambda x: x + 500).collect()
# Out:
# [1000,
#  1700,
#  3500,
#  5000,
#  1300,
#  1450,
#  1600,
#  3000,
#  4500,
#  6500,
#  1250,
#  2300,
#  2700,
#  3800,
#  5200,
#  5700,
#  2000,
#  3100,
#  4200,
#  5300,
#  6400,
#  6700,
#  1200,
#  1400,
#  1900,
#  2250,
#  2600,
#  3400,
#  4100,
#  4800,
#  5600,
#  6300,
#  7000,
#  7700,
#  8600,
#  9700,
#  11000,
#  12500,
#  14000,
#  15500,
#  17500,
#  19500,
#  22500,
#  25500,
#  28500,
#  30500,
#  32500,
#  35500,
#  38500,
#  40500]

# %%
# 58
amount_rdd.map(lambda x: x+ (x/2)).collect()
# Out:
# [750.0,
#  1800.0,
#  4500.0,
#  6750.0,
#  1200.0,
#  1425.0,
#  1650.0,
#  3750.0,
#  6000.0,
#  9000.0,
#  1125.0,
#  2700.0,
#  3300.0,
#  4950.0,
#  7050.0,
#  7800.0,
#  2250.0,
#  3900.0,
#  5550.0,
#  7200.0,
#  8850.0,
#  9300.0,
#  1050.0,
#  1350.0,
#  2100.0,
#  2625.0,
#  3150.0,
#  4350.0,
#  5400.0,
#  6450.0,
#  7650.0,
#  8700.0,
#  9750.0,
#  10800.0,
#  12150.0,
#  13800.0,
#  15750.0,
#  18000.0,
#  20250.0,
#  22500.0,
#  25500.0,
#  28500.0,
#  33000.0,
#  37500.0,
#  42000.0,
#  45000.0,
#  48000.0,
#  52500.0,
#  57000.0,
#  60000.0]

# %%
# 59
amount_rdd.sortBy(lambda x: x).collect()
# Out:
# [500,
#  700,
#  750,
#  800,
#  900,
#  950,
#  1100,
#  1200,
#  1400,
#  1500,
#  1750,
#  1800,
#  2100,
#  2200,
#  2500,
#  2600,
#  2900,
#  3000,
#  3300,
#  3600,
#  3700,
#  4000,
#  4300,
#  4500,
#  4700,
#  4800,
#  5100,
#  5200,
#  5800,
#  5900,
#  6000,
#  6200,
#  6500,
#  7200,
#  8100,
#  9200,
#  10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
# 60
amount_rdd.sortBy(lambda x: x, ascending=False).collect()
# Out:
# [40000,
#  38000,
#  35000,
#  32000,
#  30000,
#  28000,
#  25000,
#  22000,
#  19000,
#  17000,
#  15000,
#  13500,
#  12000,
#  10500,
#  9200,
#  8100,
#  7200,
#  6500,
#  6200,
#  6000,
#  5900,
#  5800,
#  5200,
#  5100,
#  4800,
#  4700,
#  4500,
#  4300,
#  4000,
#  3700,
#  3600,
#  3300,
#  3000,
#  2900,
#  2600,
#  2500,
#  2200,
#  2100,
#  1800,
#  1750,
#  1500,
#  1400,
#  1200,
#  1100,
#  950,
#  900,
#  800,
#  750,
#  700,
#  500]

# %%
amount_rdd.top(10)
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
amount_rdd.sortBy(lambda x: x).take(10)
# Out:
# [500, 700, 750, 800, 900, 950, 1100, 1200, 1400, 1500]

# %%
# 63
amount_rdd.filter(lambda x: x > 5000).count()
# Out:
# 24

# %%
# 64
amount_rdd.filter(lambda x: x > 20000).count()
# Out:
# 8

# %%
# 65
amount_rdd.filter(lambda x: x > 10000).sum()
# Out:
# 337000

# %%
customer_comments = [
"service was excellent",
"mobile banking is easy",
"transfer completed quickly",
"deposit process was smooth",
"excellent customer support",
"loan payment completed successfully",
"banking app is excellent",
"service is fast and reliable"
]
comment_rdd = spark.sparkContext.parallelize(customer_comments)

# %%
# 66
comment_rdd.flatMap(lambda x: x.split()).collect()
# Out:
# ['service',
#  'was',
#  'excellent',
#  'mobile',
#  'banking',
#  'is',
#  'easy',
#  'transfer',
#  'completed',
#  'quickly',
#  'deposit',
#  'process',
#  'was',
#  'smooth',
#  'excellent',
#  'customer',
#  'support',
#  'loan',
#  'payment',
#  'completed',
#  'successfully',
#  'banking',
#  'app',
#  'is',
#  'excellent',
#  'service',
#  'is',
#  'fast',
#  'and',
#  'reliable']

# %%
# 67
comment_rdd.flatMap(lambda x: x.split()).count()
# Out:
# 30

# %%
# 68
comment_rdd.flatMap(lambda x: x.split()).distinct().collect()
# Out:
# ['service',
#  'banking',
#  'easy',
#  'transfer',
#  'deposit',
#  'support',
#  'payment',
#  'successfully',
#  'app',
#  'fast',
#  'and',
#  'reliable',
#  'was',
#  'excellent',
#  'mobile',
#  'is',
#  'completed',
#  'quickly',
#  'process',
#  'smooth',
#  'customer',
#  'loan']

# %%
# 69
comment_rdd.flatMap(lambda x: x.split()).sortBy(lambda x: x).collect()
# Out:
# ['and',
#  'app',
#  'banking',
#  'banking',
#  'completed',
#  'completed',
#  'customer',
#  'deposit',
#  'easy',
#  'excellent',
#  'excellent',
#  'excellent',
#  'fast',
#  'is',
#  'is',
#  'is',
#  'loan',
#  'mobile',
#  'payment',
#  'process',
#  'quickly',
#  'reliable',
#  'service',
#  'service',
#  'smooth',
#  'successfully',
#  'support',
#  'transfer',
#  'was',
#  'was']

# %%
# 70
comment_rdd.flatMap(lambda x: x.split()).countByValue()
# Out:
# defaultdict(int,
#             {'service': 2,
#              'was': 2,
#              'excellent': 3,
#              'mobile': 1,
#              'banking': 2,
#              'is': 3,
#              'easy': 1,
#              'transfer': 1,
#              'completed': 2,
#              'quickly': 1,
#              'deposit': 1,
#              'process': 1,
#              'smooth': 1,
#              'customer': 1,
#              'support': 1,
#              'loan': 1,
#              'payment': 1,
#              'successfully': 1,
#              'app': 1,
#              'fast': 1,
#              'and': 1,
#              'reliable': 1})

# %%
# 71
comment_rdd.filter(lambda x: "service" in x).collect()
# Out:
# ['service was excellent', 'service is fast and reliable']

# %%
# 72
comment_rdd.filter(lambda x: "excellent" in x).collect()
# Out:
# ['service was excellent',
#  'excellent customer support',
#  'banking app is excellent']

# %%
# 73
comment_rdd.map(lambda x: x.upper()).collect()
# Out:
# ['SERVICE WAS EXCELLENT',
#  'MOBILE BANKING IS EASY',
#  'TRANSFER COMPLETED QUICKLY',
#  'DEPOSIT PROCESS WAS SMOOTH',
#  'EXCELLENT CUSTOMER SUPPORT',
#  'LOAN PAYMENT COMPLETED SUCCESSFULLY',
#  'BANKING APP IS EXCELLENT',
#  'SERVICE IS FAST AND RELIABLE']

# %%
# 74
words = comment_rdd.flatMap(lambda x: x.split())
words.reduce(lambda x,y: x if len(x) > len(y) else y)
# Out:
# 'successfully'

# %%
# 75
words.reduce(lambda x,y: x if len(x) < len(y) else y)
# Out:
# 'is'

# %%
# 76
com_cnts = words.countByValue()
max(com_cnts.items(), key=lambda x: x[1])
# Out:
# ('excellent', 3)

# %%
# 77
min(com_cnts.items(), key=lambda x: x[1])
# Out:
# ('mobile', 1)

# %%
# 78
words.filter(lambda x: x.startswith("b")).collect()
# Out:
# ['banking', 'banking']

# %%
# 79
words.filter(lambda x: x.endswith("ly")).collect()
# Out:
# ['quickly', 'successfully']

# %%
# 80
print("Length of comments : ",comment_rdd.count())
print("Total words in comments : ",words.count())
print("Distinct words in comments : ",words.distinct().count())
print("Frequency of words: ",dict(words.countByValue()))
# Out:
# Length of comments :  8
# Total words in comments :  30
# Distinct words in comments :  22
# Frequency of words:  {'service': 2, 'was': 2, 'excellent': 3, 'mobile': 1, 'banking': 2, 'is': 3, 'easy': 1, 'transfer': 1, 'completed': 2, 'quickly': 1, 'deposit': 1, 'process': 1, 'smooth': 1, 'customer': 1, 'support': 1, 'loan': 1, 'payment': 1, 'successfully': 1, 'app': 1, 'fast': 1, 'and': 1, 'reliable': 1}

# %%
# 81
trans_cnts = rdd.countByValue()
(trans_cnts['DEPOSIT'] / rdd.count()) *100
# Out:
# 32.0

# %%
# 82
(trans_cnts['TRANSFER'] / rdd.count()) *100
# Out:
# 26.0

# %%
# 83
(trans_cnts['WITHDRAW'] / rdd.count()) *100
# Out:
# 20.0

# %%
# 84 ?37
print(most)
# Out:
# ('DEPOSIT', 16)

# %%
# 85 38
print(least)
# Out:
# ('LOAN_PAYMENT', 5)

# %%
# 86
print("Transaction Summary Report:")
print("Total transactions:", rdd.count())
print("Distinct transactions:", rdd.distinct().count())
print("Most common transaction:", most)
print("Least common transaction:", least)
print("Transaction counts:", trans_cnts)
# Out:
# Transaction Summary Report:
# Total transactions: 50
# Distinct transactions: 5
# Most common transaction: ('DEPOSIT', 16)
# Least common transaction: ('LOAN_PAYMENT', 5)
# Transaction counts: defaultdict(<class 'int'>, {'DEPOSIT': 16, 'WITHDRAW': 10, 'TRANSFER': 13, 'BALANCE_CHECK': 6, 'LOAN_PAYMENT': 5})

# %%
# 87
print("Unique Transaction report")
print("unique transaction: ",rdd.distinct().collect())
print("Total unique transaction: ",rdd.distinct().count())
# Out:
# Unique Transaction report
# unique transaction:  ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']
# Total unique transaction:  5

# %%
# 88
print("Frequency Report:")
print("Total transactions:", rdd.count())
print("Transaction counts:", rdd.countByValue())
print("Most common transaction:", most)
print("Least common transaction:", least)
# Out:
# Frequency Report:
# Total transactions: 50
# Transaction counts: defaultdict(<class 'int'>, {'DEPOSIT': 16, 'WITHDRAW': 10, 'TRANSFER': 13, 'BALANCE_CHECK': 6, 'LOAN_PAYMENT': 5})
# Most common transaction: ('DEPOSIT', 16)
# Least common transaction: ('LOAN_PAYMENT', 5)

# %%
# 89
rdd.distinct().saveAsTextFile( "distinctTransactions")

# %%
spark.read.text("distinctTransactions").show()
# Out:
# +-------------+
# |        value|
# +-------------+
# |      DEPOSIT|
# |     WITHDRAW|
# |     TRANSFER|
# |BALANCE_CHECK|
# | LOAN_PAYMENT|
# +-------------+

# %%
# 90
(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
 .saveAsTextFile("Transaction_frequency"))

# %%
spark.read.text("Transaction_frequency").show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |     ('DEPOSIT', 16)|
# |    ('WITHDRAW', 10)|
# |    ('TRANSFER', 13)|
# |('BALANCE_CHECK', 6)|
# | ('LOAN_PAYMENT', 5)|
# +--------------------+

# %%
# 91
print("Total Banking activity: ",rdd.count())
# Out:
# Total Banking activity:  50

# %%
# 92
sorted(counts.items(), key=lambda x: x[1], reverse=True)[:3]
# Out:
# [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10)]

# %%
# 93
sorted(counts.items(), key=lambda x: x[1], reverse=False)[:3]
# Out:
# [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10)]

# %%
# 94
sorted(counts.items(), key=lambda x: x[1])
# Out:
# [('LOAN_PAYMENT', 5),
#  ('BALANCE_CHECK', 6),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 13),
#  ('DEPOSIT', 16)]

# %%
# 95
print("Final Banking report")
print("Transaction Summary Report:")
print("Total transactions:", rdd.count())
print("Distinct transactions:", rdd.distinct().count())
print("Most common transaction:", most)
print("Least common transaction:", least)
print("Transaction counts:", trans_cnts)
print("Total amount:", amount_rdd.reduce(lambda x,y: x+y))
print("Average amount:", amount_rdd.reduce(lambda x,y: x+y) / amount_rdd.count())
print("Top Activities: ",sorted(counts.items(), key=lambda x: x[1], reverse=True)[:3])
print("Bottom Activities: ",sorted(counts.items(), key=lambda x: x[1], reverse=False))
# Out:
# Final Banking report
# Transaction Summary Report:
# Total transactions: 50
# Distinct transactions: 5
# Most common transaction: ('DEPOSIT', 16)
# Least common transaction: ('LOAN_PAYMENT', 5)
# Transaction counts: defaultdict(<class 'int'>, {'DEPOSIT': 16, 'WITHDRAW': 10, 'TRANSFER': 13, 'BALANCE_CHECK': 6, 'LOAN_PAYMENT': 5})
# Total amount: 463750
# Average amount: 9275.0
# Top Activities:  [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10)]
# Bottom Activities:  [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10), ('TRANSFER', 13), ('DEPOSIT', 16)]

# %%
# 96
amount_rdd.reduce(lambda x,y: x+y)
# Out:
# 463750

# %%
# 97
amount_rdd.reduce(lambda x,y: x+y) / amount_rdd.count()
# Out:
# 9275.0

# %%
# 98
amount_rdd.filter(lambda x: x > 20000).collect()
# Out:
# [22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
# 99
amount_rdd.filter(lambda x: x < 1000).collect()
# Out:
# [500, 800, 950, 750, 700, 900]

# %%
# 100
print("Complete Report :  \n")
print("Total transactions:", rdd.count())
print("Distinct transactions:", rdd.distinct().count())
print("Most common transaction:", most)
print("Least common transaction:", least)
print("Transaction counts:", trans_cnts)
print("Total amount:", amount_rdd.reduce(lambda x,y: x+y))
print("Average amount:", amount_rdd.reduce(lambda x,y: x+y) / amount_rdd.count())
print("highest amount:", amount_rdd.reduce(lambda x,y: x if x>y else y))
print("lowest amount:", amount_rdd.reduce(lambda x,y: x if x<y else y))
print("High value Transaction:",amount_rdd.filter(lambda x: x > 20000).collect())
print("Low value Transaction:",amount_rdd.filter(lambda x: x < 1000).collect())
# Out:
# Complete Report :
#
# Total transactions: 50
# Distinct transactions: 5
# Most common transaction: ('DEPOSIT', 16)
# Least common transaction: ('LOAN_PAYMENT', 5)
# Transaction counts: defaultdict(<class 'int'>, {'DEPOSIT': 16, 'WITHDRAW': 10, 'TRANSFER': 13, 'BALANCE_CHECK': 6, 'LOAN_PAYMENT': 5})
# Total amount: 463750
# Average amount: 9275.0
# highest amount: 40000
# lowest amount: 500
# High value Transaction: [22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]
# Low value Transaction: [500, 800, 950, 750, 700, 900]
