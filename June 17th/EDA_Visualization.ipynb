# %%
from pyspark.sql.functions import col 
appointments_data = [ 
(1001, "Hyderabad", "Cardiology", "Apollo", 1500, "Completed"), 
(1002, "Bangalore", "Neurology", "Yashoda", 2200, "Completed"), 
(1003, "Mumbai", "Dermatology", "Care", 900, "Pending"), 
(1004, "Delhi", "Orthopedics", "Max", 2500, "Completed"), 
(1005, "Chennai", "Pediatrics", "Apollo", 1200, "Cancelled"), 
(1006, "Hyderabad", "Cardiology", "Care", 3000, "Completed"), 
(1007, "Bangalore", "Dermatology", "Apollo", 1000, "Completed"), 
(1008, "Mumbai", "Neurology", "Max", 2600, "Pending"), 
(1009, "Delhi", "Cardiology", "Yashoda", 2800, "Completed"), 
(1010, "Chennai", "Orthopedics", "Care", 2400, "Completed"), 
(1011, "Hyderabad", "Pediatrics", "Apollo", 1100, "Completed"), 
(1012, "Bangalore", "Cardiology", "Max", 3200, "Completed"), 
(1013, "Mumbai", "Pediatrics", "Yashoda", 1300, "Cancelled"), 
(1014, "Delhi", "Neurology", "Apollo", 2700, "Completed"), 
(1015, "Chennai", "Dermatology", "Care", 950, "Pending") 
] 
columns = [ 
"appointment_id", 
"city", 
"department", 
"hospital", 
"consultation_fee", 
"status" 
] 
df = spark.createDataFrame(appointments_data, columns) 
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>city</th><th>department</th><th>hospital</th><th>consultation_fee</th><th>status</th></tr></thead><tbody><tr><td>1001</td><td>Hyderabad</td><td>Cardiology</td><td>Apollo</td><td>1500</td><td>Completed</td></tr><tr><td>1002</td><td>Bangalore</td><td>Neurology</td><td>Yashoda</td><td>2200</td><td>Completed</td></tr><tr><td>1003</td><td>Mumbai</td><td>Dermatology</td><td>Care</td><td>900</td><td>Pending</td></tr><tr><td>1004</td><td>Delhi</td><td>Orthopedics</td><td>Max</td><td>2500</td><td>Completed</td></tr><tr><td>1005</td><td>Chennai</td><td>Pediatrics</td><td>Apollo</td><td>1200</td><td>Cancelled</td></tr><tr><td>1006</td><td>Hyderabad</td><td>Cardiology</td><td>Care</td><td>3000</td><td>Completed</td></tr><tr><td>1007</td><td>Bangalore</td><td>Dermatology</td><td>Apollo</td><td>1000</td><td>Completed</td></tr><tr><td>1008</td><td>Mumbai</td><td>Neurology</td><td>Max</td><td>2600</td><td>Pending</td></tr><tr><td>1009</td><td>Delhi</td><td>Cardiology</td><td>Yashoda</td><td>2800</td><td>Completed</td></tr><tr><td>1010</td><td>Chennai</td><td>Orthopedics</td><td>Care</td><td>2400</td><td>Completed</td></tr><tr><td>1011</td><td>Hyderabad</td><td>Pediatrics</td><td>Apollo</td><td>1100</td><td>Completed</td></tr><tr><td>1012</td><td>Bangalore</td><td>Cardiology</td><td>Max</td><td>3200</td><td>Completed</td></tr><tr><td>1013</td><td>Mumbai</td><td>Pediatrics</td><td>Yashoda</td><td>1300</td><td>Cancelled</td></tr><tr><td>1014</td><td>Delhi</td><td>Neurology</td><td>Apollo</td><td>2700</td><td>Completed</td></tr><tr><td>1015</td><td>Chennai</td><td>Dermatology</td><td>Care</td><td>950</td><td>Pending</td></tr></tbody></table></div>

# %%
city_count = df.groupBy("city").count()
display(city_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td>Hyderabad</td><td>3</td></tr><tr><td>Bangalore</td><td>3</td></tr><tr><td>Mumbai</td><td>3</td></tr><tr><td>Delhi</td><td>3</td></tr><tr><td>Chennai</td><td>3</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
dept_count = df.groupBy("department").count()
display(dept_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count</th></tr></thead><tbody><tr><td>Cardiology</td><td>4</td></tr><tr><td>Neurology</td><td>3</td></tr><tr><td>Dermatology</td><td>3</td></tr><tr><td>Orthopedics</td><td>2</td></tr><tr><td>Pediatrics</td><td>3</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
status_count = df.groupBy("status").count()
display(status_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>status</th><th>count</th></tr></thead><tbody><tr><td>Completed</td><td>10</td></tr><tr><td>Pending</td><td>3</td></tr><tr><td>Cancelled</td><td>2</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
city_revenue = df.groupBy("city") \
    .sum("consultation_fee") \
    .withColumnRenamed("sum(consultation_fee)", "revenue")

display(city_revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>revenue</th></tr></thead><tbody><tr><td>Hyderabad</td><td>5600</td></tr><tr><td>Bangalore</td><td>6400</td></tr><tr><td>Mumbai</td><td>4800</td></tr><tr><td>Delhi</td><td>8000</td></tr><tr><td>Chennai</td><td>4550</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
dept_revenue = df.groupBy("department") \
    .sum("consultation_fee") \
    .withColumnRenamed("sum(consultation_fee)", "revenue")
display(dept_revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>revenue</th></tr></thead><tbody><tr><td>Cardiology</td><td>10500</td></tr><tr><td>Neurology</td><td>7500</td></tr><tr><td>Dermatology</td><td>2850</td></tr><tr><td>Orthopedics</td><td>4900</td></tr><tr><td>Pediatrics</td><td>3600</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
hospital_revenue = df.groupBy("hospital") \
    .sum("consultation_fee") \
    .withColumnRenamed("sum(consultation_fee)", "revenue")
display(hospital_revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hospital</th><th>revenue</th></tr></thead><tbody><tr><td>Apollo</td><td>7500</td></tr><tr><td>Yashoda</td><td>6300</td></tr><tr><td>Care</td><td>7250</td></tr><tr><td>Max</td><td>8300</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(df.select("appointment_id","consultation_fee").orderBy("appointment_id"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>consultation_fee</th></tr></thead><tbody><tr><td>1001</td><td>1500</td></tr><tr><td>1002</td><td>2200</td></tr><tr><td>1003</td><td>900</td></tr><tr><td>1004</td><td>2500</td></tr><tr><td>1005</td><td>1200</td></tr><tr><td>1006</td><td>3000</td></tr><tr><td>1007</td><td>1000</td></tr><tr><td>1008</td><td>2600</td></tr><tr><td>1009</td><td>2800</td></tr><tr><td>1010</td><td>2400</td></tr><tr><td>1011</td><td>1100</td></tr><tr><td>1012</td><td>3200</td></tr><tr><td>1013</td><td>1300</td></tr><tr><td>1014</td><td>2700</td></tr><tr><td>1015</td><td>950</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(df.select("appointment_id","consultation_fee"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>consultation_fee</th></tr></thead><tbody><tr><td>1001</td><td>1500</td></tr><tr><td>1002</td><td>2200</td></tr><tr><td>1003</td><td>900</td></tr><tr><td>1004</td><td>2500</td></tr><tr><td>1005</td><td>1200</td></tr><tr><td>1006</td><td>3000</td></tr><tr><td>1007</td><td>1000</td></tr><tr><td>1008</td><td>2600</td></tr><tr><td>1009</td><td>2800</td></tr><tr><td>1010</td><td>2400</td></tr><tr><td>1011</td><td>1100</td></tr><tr><td>1012</td><td>3200</td></tr><tr><td>1013</td><td>1300</td></tr><tr><td>1014</td><td>2700</td></tr><tr><td>1015</td><td>950</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display( df.filter(col("status") == "Completed"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>city</th><th>department</th><th>hospital</th><th>consultation_fee</th><th>status</th></tr></thead><tbody><tr><td>1001</td><td>Hyderabad</td><td>Cardiology</td><td>Apollo</td><td>1500</td><td>Completed</td></tr><tr><td>1002</td><td>Bangalore</td><td>Neurology</td><td>Yashoda</td><td>2200</td><td>Completed</td></tr><tr><td>1004</td><td>Delhi</td><td>Orthopedics</td><td>Max</td><td>2500</td><td>Completed</td></tr><tr><td>1006</td><td>Hyderabad</td><td>Cardiology</td><td>Care</td><td>3000</td><td>Completed</td></tr><tr><td>1007</td><td>Bangalore</td><td>Dermatology</td><td>Apollo</td><td>1000</td><td>Completed</td></tr><tr><td>1009</td><td>Delhi</td><td>Cardiology</td><td>Yashoda</td><td>2800</td><td>Completed</td></tr><tr><td>1010</td><td>Chennai</td><td>Orthopedics</td><td>Care</td><td>2400</td><td>Completed</td></tr><tr><td>1011</td><td>Hyderabad</td><td>Pediatrics</td><td>Apollo</td><td>1100</td><td>Completed</td></tr><tr><td>1012</td><td>Bangalore</td><td>Cardiology</td><td>Max</td><td>3200</td><td>Completed</td></tr><tr><td>1014</td><td>Delhi</td><td>Neurology</td><td>Apollo</td><td>2700</td><td>Completed</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *

# %%
active_df = df.filter(col("status") != "Cancelled")

revenue_active = active_df.groupBy("city") \
    .agg(sum("consultation_fee").alias("revenue"))

display(revenue_active)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>revenue</th></tr></thead><tbody><tr><td>Hyderabad</td><td>5600</td></tr><tr><td>Bangalore</td><td>6400</td></tr><tr><td>Mumbai</td><td>3500</td></tr><tr><td>Delhi</td><td>8000</td></tr><tr><td>Chennai</td><td>3350</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
import matplotlib.pyplot as plt

pdf = city_revenue.toPandas()

plt.figure(figsize=(12,6))
plt.bar(pdf["city"], pdf["revenue"])
plt.title("Revenue Analysis by City")
plt.xlabel("City")
plt.ylabel("Revenue")
plt.xticks(rotation=45)

plt.show()

# %%
top3_city = city_revenue.orderBy(col("revenue").desc()).limit(3)
display(top3_city)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>revenue</th></tr></thead><tbody><tr><td>Delhi</td><td>8000</td></tr><tr><td>Bangalore</td><td>6400</td></tr><tr><td>Hyderabad</td><td>5600</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
top3_departments = dept_revenue.orderBy(
    col("revenue").desc()
).limit(3)
display(top3_departments)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>revenue</th></tr></thead><tbody><tr><td>Cardiology</td><td>10500</td></tr><tr><td>Neurology</td><td>7500</td></tr><tr><td>Orthopedics</td><td>4900</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display( df.groupBy("hospital").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hospital</th><th>count</th></tr></thead><tbody><tr><td>Apollo</td><td>5</td></tr><tr><td>Yashoda</td><td>3</td></tr><tr><td>Care</td><td>4</td></tr><tr><td>Max</td><td>3</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
lowest_hospital = hospital_revenue.orderBy(col("revenue")).limit(1)
display(lowest_hospital)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hospital</th><th>revenue</th></tr></thead><tbody><tr><td>Yashoda</td><td>6300</td></tr></tbody></table></div>

# %%
revenue_city = (
    df.groupBy("city")
      .agg(sum("consultation_fee").alias("revenue"))
      .orderBy(col("revenue").desc())
)
display(revenue_city)

revenue_department = (
    df.groupBy("department")
      .agg(sum("consultation_fee").alias("revenue"))
      .orderBy(col("revenue").desc())
)
display(revenue_department)

status_distribution = (
    df.groupBy("status")
      .count()
)
display(status_distribution)

revenue_hospital = (
    df.groupBy("hospital")
      .agg(sum("consultation_fee").alias("revenue"))
      .orderBy(col("revenue").desc())
)
display(revenue_hospital)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>revenue</th></tr></thead><tbody><tr><td>Delhi</td><td>8000</td></tr><tr><td>Bangalore</td><td>6400</td></tr><tr><td>Hyderabad</td><td>5600</td></tr><tr><td>Mumbai</td><td>4800</td></tr><tr><td>Chennai</td><td>4550</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>revenue</th></tr></thead><tbody><tr><td>Cardiology</td><td>10500</td></tr><tr><td>Neurology</td><td>7500</td></tr><tr><td>Orthopedics</td><td>4900</td></tr><tr><td>Pediatrics</td><td>3600</td></tr><tr><td>Dermatology</td><td>2850</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>status</th><th>count</th></tr></thead><tbody><tr><td>Completed</td><td>10</td></tr><tr><td>Pending</td><td>3</td></tr><tr><td>Cancelled</td><td>2</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hospital</th><th>revenue</th></tr></thead><tbody><tr><td>Max</td><td>8300</td></tr><tr><td>Apollo</td><td>7500</td></tr><tr><td>Care</td><td>7250</td></tr><tr><td>Yashoda</td><td>6300</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
import matplotlib.pyplot as plt

city_pdf = city_revenue.toPandas()
dept_pdf = dept_revenue.toPandas()
status_pdf = status_count.toPandas()
hospital_pdf = hospital_revenue.toPandas()

fig, axs = plt.subplots(2,2, figsize=(16,12))

axs[0,0].bar(city_pdf["city"], city_pdf["revenue"])
axs[0,0].set_title("Revenue by City")

axs[0,1].bar(dept_pdf["department"], dept_pdf["revenue"])
axs[0,1].set_title("Revenue by Department")

axs[1,0].pie(
    status_pdf["count"],
    labels=status_pdf["status"],
    autopct="%1.1f%%"
)
axs[1,0].set_title("Appointment Status")

axs[1,1].barh(
    hospital_pdf["hospital"],
    hospital_pdf["revenue"]
)
axs[1,1].set_title("Revenue by Hospital")
plt.tight_layout()
plt.show()

# %%
display(df.select( "appointment_id","consultation_fee") .orderBy("appointment_id"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>consultation_fee</th></tr></thead><tbody><tr><td>1001</td><td>1500</td></tr><tr><td>1002</td><td>2200</td></tr><tr><td>1003</td><td>900</td></tr><tr><td>1004</td><td>2500</td></tr><tr><td>1005</td><td>1200</td></tr><tr><td>1006</td><td>3000</td></tr><tr><td>1007</td><td>1000</td></tr><tr><td>1008</td><td>2600</td></tr><tr><td>1009</td><td>2800</td></tr><tr><td>1010</td><td>2400</td></tr><tr><td>1011</td><td>1100</td></tr><tr><td>1012</td><td>3200</td></tr><tr><td>1013</td><td>1300</td></tr><tr><td>1014</td><td>2700</td></tr><tr><td>1015</td><td>950</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>city</th><th>department</th><th>hospital</th><th>consultation_fee</th><th>status</th></tr></thead><tbody><tr><td>1001</td><td>Hyderabad</td><td>Cardiology</td><td>Apollo</td><td>1500</td><td>Completed</td></tr><tr><td>1002</td><td>Bangalore</td><td>Neurology</td><td>Yashoda</td><td>2200</td><td>Completed</td></tr><tr><td>1003</td><td>Mumbai</td><td>Dermatology</td><td>Care</td><td>900</td><td>Pending</td></tr><tr><td>1004</td><td>Delhi</td><td>Orthopedics</td><td>Max</td><td>2500</td><td>Completed</td></tr><tr><td>1005</td><td>Chennai</td><td>Pediatrics</td><td>Apollo</td><td>1200</td><td>Cancelled</td></tr><tr><td>1006</td><td>Hyderabad</td><td>Cardiology</td><td>Care</td><td>3000</td><td>Completed</td></tr><tr><td>1007</td><td>Bangalore</td><td>Dermatology</td><td>Apollo</td><td>1000</td><td>Completed</td></tr><tr><td>1008</td><td>Mumbai</td><td>Neurology</td><td>Max</td><td>2600</td><td>Pending</td></tr><tr><td>1009</td><td>Delhi</td><td>Cardiology</td><td>Yashoda</td><td>2800</td><td>Completed</td></tr><tr><td>1010</td><td>Chennai</td><td>Orthopedics</td><td>Care</td><td>2400</td><td>Completed</td></tr><tr><td>1011</td><td>Hyderabad</td><td>Pediatrics</td><td>Apollo</td><td>1100</td><td>Completed</td></tr><tr><td>1012</td><td>Bangalore</td><td>Cardiology</td><td>Max</td><td>3200</td><td>Completed</td></tr><tr><td>1013</td><td>Mumbai</td><td>Pediatrics</td><td>Yashoda</td><td>1300</td><td>Cancelled</td></tr><tr><td>1014</td><td>Delhi</td><td>Neurology</td><td>Apollo</td><td>2700</td><td>Completed</td></tr><tr><td>1015</td><td>Chennai</td><td>Dermatology</td><td>Care</td><td>950</td><td>Pending</td></tr></tbody></table></div>
