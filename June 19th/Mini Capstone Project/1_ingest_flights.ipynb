# %%
flights_df = spark.read.csv(
    '/Volumes/airline_databricks_7405614278006752/default/datasets/Flights.csv',
    header=True,
    inferSchema=True
)

# %%
flights_df.printSchema()
# Out:
# root
#  |-- flight_id: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- from_city: string (nullable = true)
#  |-- to_city: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- status: string (nullable = true)

# %%
display(flights_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
flights_df.write.mode('overwrite').saveAsTable('flights')
